# %% [markdown]
# <a href="https://colab.research.google.com/github/kunj1674/ML_Winnovation/blob/master/Height_Pridiction_Modal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/drive/MyDrive/weight-height.csv')
df.head(11)
# Out:
#    Gender     Height      Weight
# 0    Male  73.847017  241.893563
# 1    Male  68.781904  162.310473
# 2    Male  74.110105  212.740856
# 3    Male  71.730978  220.042470
# 4    Male  69.881796  206.349801
# 5    Male  67.253016  152.212156
# 6    Male  68.785081  183.927889
# 7    Male  68.348516  167.971110
# 8    Male  67.018950  175.929440
# 9    Male  63.456494  156.399676
# 10   Male  71.195382  186.604926

# %%
df.shape
# Out:
# (10000, 3)

# %%
df.groupby(['Gender'])['Height'].mean()
# Out:
# Gender
# Female    63.708774
# Male      69.026346
# Name: Height, dtype: float64

# %%
df.groupby(['Gender'])['Height'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['Gender'], df['Height'])
plt.xlabel('Gender')
plt.ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['Weight'], df['Height'])
plt.xlabel('Weight')
plt.ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')

# %%
df['Male_candidate'] = np.where(df['Gender']=='Male', 1, 0)
df['Female_candidate'] = np.where(df['Gender']=='Female', 1, 0)

# %%
df.sample(11)
# Out:
#       Gender     Height      Weight  Male_candidate  Female_candidate
# 2630    Male  68.224860  186.197250               1                 0
# 8563  Female  62.985898  112.573791               0                 1
# 2188    Male  68.663594  184.262796               1                 0
# 9552  Female  64.215125  145.821458               0                 1
# 4003    Male  68.919604  194.278451               1                 0
# 6289  Female  57.675181  125.941865               0                 1
# 6046  Female  67.729082  147.505871               0                 1
# 6937  Female  65.647055  143.929981               0                 1
# 4868    Male  70.930929  188.703885               1                 0
# 2640    Male  68.602413  186.965591               1                 0
# 8184  Female  64.762147  142.264983               0                 1

# %%
df.drop(columns = ['Gender'], inplace = True)

# %%
df.sample(11)
# Out:
#          Height      Weight  Male_candidate  Female_candidate
# 2919  70.358522  201.601812               1                 0
# 4397  67.017848  156.544812               1                 0
# 2429  70.981607  191.138848               1                 0
# 2288  68.783873  187.635464               1                 0
# 4637  59.868078  117.803842               1                 0
# 7168  64.258261  144.080612               0                 1
# 813   69.639709  197.596213               1                 0
# 7774  66.337658  155.668743               0                 1
# 1740  66.916335  175.203935               1                 0
# 3034  71.363595  212.594865               1                 0
# 5644  65.034537  145.706062               0                 1

# %%
x = df.drop(columns = ['Height'])
y = df['Height']

# %%
x.head(5)
# Out:
#        Weight  Male_candidate  Female_candidate
# 0  241.893563               1                 0
# 1  162.310473               1                 0
# 2  212.740856               1                 0
# 3  220.042470               1                 0
# 4  206.349801               1                 0

# %%
y.head(5)
# Out:
# 0    73.847017
# 1    68.781904
# 2    74.110105
# 3    71.730978
# 4    69.881796
# Name: Height, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 51)

# %%
x_train.shape
# Out:
# (8000, 3)

# %%
x_test.shape
# Out:
# (2000, 3)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 0.12312502, -0.48938071,  0.48938071])

# %%
x_train.head(1)
# Out:
#           Weight  Male_candidate  Female_candidate
# 4013  158.439049               1                 0

# %%
model.predict([[158.439049,	1,0]])
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65.52345369])

# %%
y_train.head(1)
# Out:
# 4013    67.434914
# Name: Height, dtype: float64

# %%
x_train.head(3)
# Out:
#           Weight  Male_candidate  Female_candidate
# 4013  158.439049               1                 0
# 7046  159.949726               0                 1
# 7941  137.927244               0                 1

# %%
y_train.head(3)
# Out:
# 4013    67.434914
# 7046    67.511362
# 7941    62.834760
# Name: Height, dtype: float64

# %%
model.predict([[159.949726,0,1]])
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([66.68821726])

# %%
model.predict([[137.927244,0,1]])
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([63.97669863])
